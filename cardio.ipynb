# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("cardio_train.csv",delimiter=';')
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %% [markdown]
# ## Categorical Relations
# id-id number
#
# age-days
#
# gender-1:women,2;men
#
# height-cm
#
# weight-kg
#
# ap_hi-systolic blood pressure
#
# ap_lo-diastolic blood pressure
#
# cholestrol-1:normal,2:above normal,3:well above normal
#
# gluc-1:normal,2:above normal,3:well above normal
#
# smoke-1:smokes,0:doesn't smokes
#
# alco-1:drinks,0:doesn't drinks
#
# active-1:yes,0:no
#
# cardio-1:yes,0:no    --    Target Variable

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
import seaborn as sns
corrmat=df.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
correlation_with_output = df.corr()['cardio'].drop('cardio')

plt.figure(figsize=(10, 6))
sns.barplot(x=correlation_with_output.values, y=correlation_with_output.index, palette='coolwarm')
plt.title('Correlation with Output Variable')
plt.xlabel('Correlation Coefficient')
plt.ylabel('Feature')
plt.show()

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'id'}>, <Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'gender'}>,
#         <Axes: title={'center': 'height'}>],
#        [<Axes: title={'center': 'weight'}>,
#         <Axes: title={'center': 'ap_hi'}>,
#         <Axes: title={'center': 'ap_lo'}>,
#         <Axes: title={'center': 'cholesterol'}>],
#        [<Axes: title={'center': 'gluc'}>,
#         <Axes: title={'center': 'smoke'}>,
#         <Axes: title={'center': 'alco'}>,
#         <Axes: title={'center': 'active'}>],
#        [<Axes: title={'center': 'cardio'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
sns.countplot(x='cardio',data=df)
# Out:
# <Axes: xlabel='cardio', ylabel='count'>

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
dataset=df.copy()
dataset
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
standardScaler=StandardScaler()
columns_to_scale=['age','height','weight','ap_hi','ap_lo']
dataset[columns_to_scale]=standardScaler.fit_transform(dataset[columns_to_scale])

# %%
dataset
# Out:
#           id       age  gender    height    weight     ap_hi     ap_lo  \
# 0          0 -0.436062       2  0.443452 -0.847873 -0.122182 -0.088238
# 1          1  0.307686       1 -1.018168  0.749831  0.072610 -0.035180
# 2          2 -0.247997       1  0.078047 -0.708942  0.007679 -0.141297
# 3          3 -0.748152       2  0.565254  0.541435  0.137541  0.017879
# 4          4 -0.808543       1 -1.018168 -1.264666 -0.187113 -0.194356
# ...      ...       ...     ...       ...       ...       ...       ...
# 69995  99993 -0.092762       2  0.443452  0.124642 -0.057251 -0.088238
# 69996  99995  1.269492       1 -0.774565  3.597913  0.072610 -0.035180
# 69997  99996 -0.163286       2  2.270477  2.139139  0.332333 -0.035180
# 69998  99998  1.200589       1 -0.165556 -0.153219  0.040145 -0.088238
# 69999  99999  0.434144       1  0.687055 -0.153219 -0.057251 -0.088238
#
#        cholesterol  gluc  smoke  alco  active  cardio
# 0                1     1      0     0       1       0
# ...

# %%
y=dataset['cardio']
x=dataset.drop(['cardio'],axis=1)
x=x.drop(['id'],axis=1)
x=x.drop(['gender'],axis=1)
x=x.drop(['alco'],axis=1)
x=x.drop(['smoke'],axis=1)
x=x.drop(['height'],axis=1)
x
# Out:
#             age    weight     ap_hi     ap_lo  cholesterol  gluc  active
# 0     -0.436062 -0.847873 -0.122182 -0.088238            1     1       1
# 1      0.307686  0.749831  0.072610 -0.035180            3     1       1
# 2     -0.247997 -0.708942  0.007679 -0.141297            3     1       0
# 3     -0.748152  0.541435  0.137541  0.017879            1     1       1
# 4     -0.808543 -1.264666 -0.187113 -0.194356            1     1       0
# ...         ...       ...       ...       ...          ...   ...     ...
# 69995 -0.092762  0.124642 -0.057251 -0.088238            1     1       1
# 69996  1.269492  3.597913  0.072610 -0.035180            2     2       1
# 69997 -0.163286  2.139139  0.332333 -0.035180            3     1       0
# 69998  1.200589 -0.153219  0.040145 -0.088238            1     2       0
# 69999  0.434144 -0.153219 -0.057251 -0.088238            2     1       1
#
# [70000 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
x_train = np.array(x_train, order='C')
x_test = np.array(x_test, order='C')

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=21)
knn.fit(x_train,y_train)
pred=knn.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,pred))
# Out:
# [[7800 2696]
#  [3360 7144]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72     10496
#            1       0.73      0.68      0.70     10504
#
#     accuracy                           0.71     21000
#    macro avg       0.71      0.71      0.71     21000
# weighted avg       0.71      0.71      0.71     21000

# %%
error_rate=[]
for i in range(1,32):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    pred_i=knn.predict(x_test)
    error_rate.append(np.mean(pred_i!=y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,32),error_rate,color='blue',linestyle='dashed',marker='o',markerfacecolor='red',markersize=10)
plt.title('Error Rate vs K.Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=13)
knn.fit(x_train,y_train)
pred=knn.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,pred))
# Out:
# [[7348 3134]
#  [3825 6693]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.70      0.68     10482
#            1       0.68      0.64      0.66     10518
#
#     accuracy                           0.67     21000
#    macro avg       0.67      0.67      0.67     21000
# weighted avg       0.67      0.67      0.67     21000

# %% [markdown]
# ### SVM

# %%
from sklearn import svm
classifier=svm.SVC(kernel='sigmoid')
classifier.fit(x_train,y_train)
pred=classifier.predict(x_test)

# %%
from sklearn import svm
from joblib import parallel_backend

# Specify the number of CPU cores to use for parallel processing
n_jobs = -1  # Set to -1 to use all available CPU cores, or specify a number

# Use parallel processing for SVM training
with parallel_backend('threading', n_jobs=n_jobs):
    # Create SVM classifier with linear kernel
    classifier = svm.SVC(kernel='linear')
    
    # Fit the classifier to the training data
    classifier.fit(x_train, y_train)

# After training, predict using the trained classifier
pred = classifier.predict(x_test)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.81      0.74     10488
#            1       0.77      0.63      0.69     10512
#
#     accuracy                           0.72     21000
#    macro avg       0.73      0.72      0.72     21000
# weighted avg       0.73      0.72      0.72     21000

# %% [markdown]
#  ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Create a Random Forest classifier object
classifier = RandomForestClassifier(n_estimators=200,random_state=20)

# Train the classifier on the training data
classifier.fit(x_train, y_train)

# Make predictions on the test data
predictions = classifier.predict(x_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.72      0.71     10488
#            1       0.71      0.70      0.71     10512
#
#     accuracy                           0.71     21000
#    macro avg       0.71      0.71      0.71     21000
# weighted avg       0.71      0.71      0.71     21000

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[8492 2011]
#  [3802 6695]]

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# Create a logistic regression classifier object
classifier = LogisticRegression()

# Train the classifier on the training data
classifier.fit(x_train, y_train)

# Make predictions on the test data
predictions = classifier.predict(x_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.76      0.73     10488
#            1       0.74      0.68      0.71     10512
#
#     accuracy                           0.72     21000
#    macro avg       0.72      0.72      0.72     21000
# weighted avg       0.72      0.72      0.72     21000
